# %%
from test_solver import test_solve_cube

# %%
test_solve_cube()
# Out:
# -------------------------------------------------------------------------------------------------------------------------------------------------------------
# Shuffle Sequence:  ["F'", "B'", 'D', 'L', "L'", 'U', 'U', "D'", "B'", "D'", "R'", 'R', "F'", 'F', "D'", 'U', 'L', "L'", 'U', "L'", 'B', "R'", 'F', 'D', "U'", 'R', 'B', 'B', "F'", "F'", "B'", 'U', "U'", 'L', 'U', 'U', "L'", "L'", "R'", "F'", 'D', "B'", 'U', 'D', 'D', 'B', "L'", "F'", 'L', 'L', "L'", 'B', "U'", 'B', "F'", 'R', "F'", "R'", "R'", 'F', "F'", 'B', "F'", "U'", "F'", 'L', 'R', 'D', 'R', 'R', 'B', "R'", 'B', "F'", "B'", 'U', "D'", 'L', "F'", 'U', "U'", 'L', 'B', 'R', "F'", 'R', "D'", 'U', "F'", "B'", "B'", "L'", 'U', 'B', "B'", 'R', "D'", "F'", "B'", "L'"]
#          b  w  o
#          w  y  y
#          g  o  b
# r  o  w  o  b  y  o  o  w  b  b  w
# r  o  g  w  b  y  g  r  g  o  g  b
# g  b  r  b  y  g  w  w  y  o  r  y
#          y  r  r
#          y  w  r
#          r  g  g
#
# 0 Solved!
# 4.253864288330078 ms
# ...
